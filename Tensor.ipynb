# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhijais/Machine-Learning-Code/blob/main/Tensor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a=np.array(3)

# %%
a
# Out:
# array(3)

# %%
a.ndim  # find dimensions
# Out:
# 0

# %%
a=np.array([1,3,3,5])
print(a)
a.ndim # 1 D Tensor
# Out:
# [1 3 3 5]
# 1

# %%
mat=np.array([[1,2,3],[2,4,5],[2,5,3]])

# %%
mat
# Out:
# array([[1, 2, 3],
#        [2, 4, 5],
#        [2, 5, 3]])

# %%
mat.ndim  # 2D Tensor
# Out:
# 2
